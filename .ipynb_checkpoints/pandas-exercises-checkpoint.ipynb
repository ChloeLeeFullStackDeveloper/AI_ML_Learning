# %% [markdown]
# # Pandas Practice
#
# This notebook is dedicated to practicing different tasks with pandas. The solutions are available in a solutions notebook, however, you should always try to figure them out yourself first.
#
# It should be noted there may be more than one different way to answer a question or complete an exercise.
#
# Exercises are based off (and directly taken from) the quick introduction to pandas notebook.
#
# Different tasks will be detailed by comments or text.
#
# For further reference and resources, it's advised to check out the [pandas documentation](https://pandas.pydata.org/pandas-docs/stable/).

# %%
# Import pandas
import pandas as pd

# %%
# Create a series of three different colours
colours = pd.Series(["Red", "Green", "Yellow"])

# %%
# View the series of different colours
colours
# Out:
# 0       Red
# 1     Green
# 2    Yellow
# dtype: object

# %%
# Create a series of three different car types and view it
car = pd.Series(["SUV", "Truck", "Van"])
car
# Out:
# 0      SUV
# 1    Truck
# 2      Van
# dtype: object

# %%
# Combine the Series of cars and colours into a DataFrame
car_data = pd.DataFrame({"Car type": car, "Colour": colours})
car_data
# Out:
#   Car type  Colour
# 0      SUV     Red
# 1    Truck   Green
# 2      Van  Yellow

# %%
# Import "../data/car-sales.csv" and turn it into a DataFrame
car_sales = pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# **Note:** Since you've imported `../data/car-sales.csv` as a DataFrame, we'll now refer to this DataFrame as 'the car sales DataFrame'.

# %%
# Export the DataFrame you created to a .csv file
car_sales.to_csv("exported-car-sales_exercise.csv", index=False)

# %%
# Find the different datatypes of the car data DataFrame
exported_car_sales_exercise = pd.read_csv("exported-car-sales_exercise.csv")
exported_car_sales_exercise
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# Describe your current car sales DataFrame using describe()
exported_car_sales_exercise.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
# Get information about your DataFrame using info()
exported_car_sales_exercise.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %% [markdown]
# What does it show you?
# 	•	There are 10 rows and 5 columns.
# 	•	The columns are Make, Colour, Odometer (KM), Doors, and Price.
# 	•	Make, Colour, and Price are stored as  object  type.
# 	•	Odometer (KM) and Doors are stored as  int64 .
# 	•	There are no missing values in any column, since each has  10 non-null  entries.
# 	•	The DataFrame uses about 528 bytes of memory.

# %%
# Create a Series of different numbers and find the mean of them
exported_car_sales_exercise.mean(numeric_only=True)
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
# Create a Series of different numbers and find the sum of them
exported_car_sales_exercise.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
# List out all the column names of the car sales DataFrame
exported_car_sales_exercise.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
# Find the length of the car sales DataFrame
len(exported_car_sales_exercise)
# Out:
# 10

# %%
# Show the first 5 rows of the car sales DataFrame
exported_car_sales_exercise.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
# Show the first 7 rows of the car sales DataFrame
exported_car_sales_exercise.head(7)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00

# %%
# Show the bottom 5 rows of the car sales DataFrame
exported_car_sales_exercise.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
# Use .loc to select the row at index 3 of the car sales DataFrame
exported_car_sales_exercise.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
# Use .iloc to select the row at position 3 of the car sales DataFrame
exported_car_sales_exercise.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %% [markdown]
# Notice how they're the same? Why do you think this is?
#
# Check the pandas documentation for [.loc](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.loc.html) and [.iloc](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.iloc.html). Think about a different situation each could be used for and try them out.
#
# They look the same here because your DataFrame’s index is the default integer index  0, 1, 2, 3, ... , so the row label and the row position happen to match.  loc  selects by label, while  iloc  selects by position, so they only behave the same when the index labels are the same as the row numbers.
# A different situation where they differ is when the index is changed. For example, if you set the index to a column like  Make , then  loc"Toyota"  would find the row labeled  "Toyota" , but  iloc  would still return the first row no matter what its label is.

# %%
# Select the "Odometer (KM)" column from the car sales DataFrame
exported_car_sales_exercise["Odometer (KM)"]
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
# Find the mean of the "Odometer (KM)" column in the car sales DataFrame
exported_car_sales_exercise["Odometer (KM)"].mean(numeric_only=True)
# Out:
# np.float64(78601.4)

# %%
# Select the rows with over 100,000 kilometers on the Odometer
exported_car_sales_exercise[exported_car_sales_exercise["Odometer (KM)"] > 100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
# Create a crosstab of the Make and Doors columns
pd.crosstab(exported_car_sales_exercise["Make"], exported_car_sales_exercise["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
# Group columns of the car sales DataFrame by the Make column and find the average
exported_car_sales_exercise.groupby(["Make"]).mean(numeric_only=True)
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
# Import Matplotlib and create a plot of the Odometer column
# Don't forget to use %matplotlib inline
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
# Create a histogram of the Odometer column using hist()
exported_car_sales_exercise["Odometer (KM)"].hist()
# Out:
# <Axes: >

# %%
# Try to plot the Price column using plot()
exported_car_sales_exercise["Price"].dtype
exported_car_sales_exercise["Price"].plot()
# Out:
# <Axes: >

# %% [markdown]
# Why didn't it work? Can you think of a solution?
#
# You might want to search for "how to convert a pandas string column to numbers".
#
# And if you're still stuck, check out this [Stack Overflow question and answer on turning a price column into integers](https://stackoverflow.com/questions/44469313/price-column-object-to-int-in-pandas).
#
# See how you can provide the example code there to the problem here.
#
# It didn’t work because  Price  is not clean numeric text yet, and some values still contain symbols like  $  and commas. Also, once you convert the column, running  .str  again can fail because the column is no longer string-like.
# Use a conversion that strips non-numeric characters first, then turns the result into numbers. A common solution is:
#
# exported_car_sales_exercise["Price"] = (
#     exported_car_sales_exercise["Price"]
#     .astype(str)
#     .str.replace(r"[\$,]", "", regex=True)
#     .astype(float)
# )
#
# # A safer alternative is:
# exported_car_sales_exercise["Price"] = pd.to_numeric(
#     exported_car_sales_exercise["Price"].astype(str).str.replace(r"[\$,]", "", regex=True),
#     errors="coerce"
# )
# # Then plot it with:
# exported_car_sales_exercise["Price"].plot()

# %%
# Remove the punctuation from price column
exported_car_sales_exercise["Price"] = pd.to_numeric(exported_car_sales_exercise["Price"])
exported_car_sales_exercise["Price"] = (
    exported_car_sales_exercise["Price"]
    .astype(str)
    .str.replace(r"[\$,\.]", "", regex=True)
)

# %%
# Check the changes to the price column
exported_car_sales_exercise["Price"]
# Out:
# 0     4000
# 1     5000
# 2     7000
# 3    22000
# 4     3500
# 5     4500
# 6     7500
# 7     7000
# 8     6250
# 9     9700
# Name: Price, dtype: object

# %%
# Remove the two extra zeros at the end of the price column
exported_car_sales_exercise["Price"] = (
    exported_car_sales_exercise["Price"]
    .astype(str)
    .str.replace(r"[\$,]", "", regex=True)
    .astype(int)
)

# %%
# Check the changes to the Price column
exported_car_sales_exercise["Price"]
# Out:
# 0     4000
# 1     5000
# 2     7000
# 3    22000
# 4     3500
# 5     4500
# 6     7500
# 7     7000
# 8     6250
# 9     9700
# Name: Price, dtype: int64

# %%
# Change the datatype of the Price column to integers
exported_car_sales_exercise["Price"] = (
    exported_car_sales_exercise["Price"]
    .astype(str)
    .str.replace(r"[\$,\.]", "", regex=True)
    .astype(int)
)
exported_car_sales_exercise["Price"].dtype
# Out:
# dtype('int64')

# %%
# Lower the strings of the Make column
exported_car_sales_exercise["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %% [markdown]
# If you check the car sales DataFrame, you'll notice the Make column hasn't been lowered.
#
# How could you make these changes permanent?
#
# Try it out.
#
# To make the lowercase change permanent, you need to assign the result back to the  Make  column. Methods like  .str.lower()  return a new Series; they do not modify the column unless you store the result.
# Use:
# exported_car_sales_exercise["Make"] = exported_car_sales_exercise["Make"].str.lower()

# %%
# Make lowering the case of the Make column permanent
exported_car_sales_exercise["Make"] = exported_car_sales_exercise["Make"].str.lower()

# %%
# Check the car sales DataFrame
exported_car_sales_exercise["Make"]
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %% [markdown]
# Notice how the Make column stays lowered after reassigning.
#
# Now let's deal with missing data.

# %%
# Import the car sales DataFrame with missing data ("../data/car-sales-missing-data.csv")
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")
# Check out the new DataFrame
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %% [markdown]
# Notice the missing values are represented as `NaN` in pandas DataFrames.
#
# Let's try fill them.

# %%
# Fill the Odometer column missing values with the mean of the column inplace
car_sales_missing["Odometer"] = car_sales_missing["Odometer"].fillna(mean_odometer)

# %%
# View the car sales missing DataFrame and verify the changes
car_sales_missing.head()
car_sales_missing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Make      9 non-null      object
#  1   Colour    9 non-null      object
#  2   Odometer  10 non-null     float64
#  3   Doors     9 non-null      float64
#  4   Price     8 non-null      object
# dtypes: float64(2), object(3)
# memory usage: 528.0+ bytes

# %%
# Remove the rest of the missing data inplace
car_sales_missing.dropna(inplace=True)

# %%
# Verify the missing values are removed by viewing the DataFrame
car_sales_missing.head()
car_sales_missing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, 0 to 5
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Make      6 non-null      object
#  1   Colour    6 non-null      object
#  2   Odometer  6 non-null      float64
#  3   Doors     6 non-null      float64
#  4   Price     6 non-null      object
# dtypes: float64(2), object(3)
# memory usage: 288.0+ bytes

# %% [markdown]
# We'll now start to add columns to our DataFrame.

# %%
# Create a "Seats" column where every row has a value of 5
seats_column = pd.Series([5,5,5,5,5,])

# New column called seats
car_sales_missing["Seats"] = seats_column
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price  Seats
# 0  Toyota  White  150043.000000    4.0   $4,000    5.0
# 1   Honda    Red   87899.000000    4.0   $5,000    5.0
# 2  Toyota   Blue   92302.666667    3.0   $7,000    5.0
# 3     BMW  Black   11179.000000    5.0  $22,000    5.0
# 4  Nissan  White  213095.000000    4.0   $3,500    5.0
# 5  Toyota  Green   92302.666667    4.0   $4,500    NaN

# %%
# Create a column called "Engine Size" with random values between 1.3 and 4.5
# Remember: If you're doing it from a Python list, the list has to be the same length
# as the DataFrame
import random

car_sales_missing["Engine Size"] = [random.uniform(1.3, 4.5) for _ in range(len(car_sales_missing))]

# %%
# Create a column which represents the price of a car per kilometer
# Then view the DataFrame
car_sales_missing["Price"] = car_sales_missing["Price"].astype(str).str.replace(r"[\$,]", "", regex=True).astype(float)

car_sales_missing["Price per KM"] = car_sales_missing["Price"] / car_sales_missing["Odometer"]
car_sales_missing.head()
# Out:
#      Make Colour       Odometer  Doors    Price  Seats  Engine Size  \
# 0  Toyota  White  150043.000000    4.0   4000.0    5.0     4.136391
# 1   Honda    Red   87899.000000    4.0   5000.0    5.0     3.653804
# 2  Toyota   Blue   92302.666667    3.0   7000.0    5.0     4.444895
# 3     BMW  Black   11179.000000    5.0  22000.0    5.0     3.985205
# 4  Nissan  White  213095.000000    4.0   3500.0    5.0     1.960560
#
#    Price per KM
# 0      0.026659
# 1      0.056883
# 2      0.075837
# 3      1.967976
# 4      0.016425

# %%
# Remove the last column you added using .drop()
car_sales_missing = car_sales_missing.drop("Price per KM", axis=1)

# %%
# Shuffle the DataFrame using sample() with the frac parameter set to 1
# Save the the shuffled DataFrame to a new variable
car_sales_missing.head()
# Out:
#      Make Colour       Odometer  Doors    Price  Seats  Engine Size
# 0  Toyota  White  150043.000000    4.0   4000.0    5.0     4.136391
# 1   Honda    Red   87899.000000    4.0   5000.0    5.0     3.653804
# 2  Toyota   Blue   92302.666667    3.0   7000.0    5.0     4.444895
# 3     BMW  Black   11179.000000    5.0  22000.0    5.0     3.985205
# 4  Nissan  White  213095.000000    4.0   3500.0    5.0     1.960560

# %% [markdown]
# Notice how the index numbers get moved around. The [`sample()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sample.html) function is a great way to get random samples from your DataFrame. It's also another great way to shuffle the rows by setting `frac=1`.

# %%
# Reset the indexes of the shuffled DataFrame
shuffled_car_sales = car_sales_missing.sample(frac=1).reset_index(drop=True)
shuffled_car_sales
# Out:
#      Make Colour       Odometer  Doors    Price  Seats  Engine Size
# 0  Nissan  White  213095.000000    4.0   3500.0    5.0     1.960560
# 1  Toyota  Green   92302.666667    4.0   4500.0    NaN     1.387636
# 2  Toyota  White  150043.000000    4.0   4000.0    5.0     4.136391
# 3  Toyota   Blue   92302.666667    3.0   7000.0    5.0     4.444895
# 4     BMW  Black   11179.000000    5.0  22000.0    5.0     3.985205
# 5   Honda    Red   87899.000000    4.0   5000.0    5.0     3.653804

# %% [markdown]
# Notice the index numbers have been changed to have order (start from 0).

# %%
# Change the Odometer values from kilometers to miles using a Lambda function
# Then view the DataFrame
car_sales_missing["Odometer"] = car_sales_missing["Odometer"].apply(lambda x: x * 0.621371)
car_sales_missing.head()
# Out:
#      Make Colour       Odometer  Doors    Price  Seats  Engine Size
# 0  Toyota  White   93232.368953    4.0   4000.0    5.0     4.136391
# 1   Honda    Red   54617.889529    4.0   5000.0    5.0     3.653804
# 2  Toyota   Blue   57354.200289    3.0   7000.0    5.0     4.444895
# 3     BMW  Black    6946.306409    5.0  22000.0    5.0     3.985205
# 4  Nissan  White  132411.053245    4.0   3500.0    5.0     1.960560

# %%
# Change the title of the Odometer (KM) to represent miles instead of kilometers
car_sales_missing.rename(columns={"Odometer (KM)": "Odometer (Miles)"}, inplace=True)
car_sales_missing.head()
# Out:
#      Make Colour       Odometer  Doors    Price  Seats  Engine Size
# 0  Toyota  White   93232.368953    4.0   4000.0    5.0     4.136391
# 1   Honda    Red   54617.889529    4.0   5000.0    5.0     3.653804
# 2  Toyota   Blue   57354.200289    3.0   7000.0    5.0     4.444895
# 3     BMW  Black    6946.306409    5.0  22000.0    5.0     3.985205
# 4  Nissan  White  132411.053245    4.0   3500.0    5.0     1.960560

# %% [markdown]
# ## Extensions
#
# For more exercises, check out the pandas documentation, particularly the [10-minutes to pandas section](https://pandas.pydata.org/pandas-docs/stable/user_guide/10min.html).
#
# One great exercise would be to retype out the entire section into a Jupyter Notebook of your own.
#
# Get hands-on with the code and see what it does.
#
# The next place you should check out are the [top questions and answers on Stack Overflow for pandas](https://stackoverflow.com/questions/tagged/pandas?sort=MostVotes&edited=true). Often, these contain some of the most useful and common pandas functions. Be sure to play around with the different filters!
#
# Finally, always remember, the best way to learn something new to is try it. Make mistakes. Ask questions, get things wrong, take note of the things you do most often. And don't worry if you keep making the same mistake, pandas has many ways to do the same thing and is a big library. So it'll likely take a while before you get the hang of it.
